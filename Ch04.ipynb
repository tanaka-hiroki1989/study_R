# %%
VADeaths
# Out:
#       Rural Male Rural Female Urban Male Urban Female
# 50-54 11.7        8.7         15.4        8.4
# 55-59 18.1       11.7         24.3       13.6
# 60-64 26.9       20.3         37.0       19.3
# 65-69 41.0       30.9         54.6       35.1
# 70-74 66.0       54.3         71.1       50.0

# %%
barplot(VADeaths)
# Out:
# plot without title

# %%
barplot(VADeaths,beside=TRUE)
# Out:
# plot without title

# %%
barplot(VADeaths, beside = TRUE, col = c("lightblue","mistyrose","lightcyan","lavender","cornsilk" ))
# Out:
# plot without title

# %%
hist(iris[1:50,2],col="lightblue")
# Out:
# Plot with title "Histogram of iris[1:50, 2]"

# %%
matplot(VADeaths,type="b")
# Out:
# plot without title

# %%
RL<-nrow(VADeaths);CL<-ncol(VADeaths)

# %%
matplot(VADeaths,type="b",pch=1:CL,xlab="",ylab="",axes=FALSE)
axis(1,1:RL,rownames(VADeaths)) 
axis(2); 		 	# �c���̍쐬
legend(1, max(VADeaths), colnames(VADeaths),col=1:CL,lty=1:CL)
# Out:
# plot without title

# %%
op<-par(mfrow=c(1,2),mar=c(2.5,2,1,1))

# %%
boxplot(iris[,1]~iris[,5],col="lightblue")	#��1���3�̔��Ђ��}��
# Out:
# plot without title

# %%
plot(iris[,1],iris[,3])
# Out:
# plot without title

# %%
iris.label<-rep(c("S","C","V"),rep(50,3))

# %%
text(iris[,1],iris[,3],iris.label)
# Out:
# Error in text.default(iris[, 1], iris[, 3], iris.label): plot.new has not been called yet
# Traceback:
#
# 1. text(iris[, 1], iris[, 3], iris.label)
# 2. text.default(iris[, 1], iris[, 3], iris.label)

# %%
plot(iris[,1],iris[,3],type="p",xlab="Length of Sepal",ylab="Length of Petal",cex=2,col="red")
# Out:
# plot without title

# %%
identify(iris[,1],iris[,3])
# Out:
# Error in identify.default(iris[, 1], iris[, 3]): plot.new has not been called yet
# Traceback:
#
# 1. identify(iris[, 1], iris[, 3])
# 2. identify.default(iris[, 1], iris[, 3])

# %%
plot(iris[,1],iris[,3],pch=21,cex=2,bg=c(2,3,4)[unclass(iris$Species)])
# Out:
# plot without title

# %%
install.packages("car")
# Out:
# also installing the dependencies 'colorspace', 'farver', 'labeling', 'munsell', 'RColorBrewer', 'viridisLite', 'diffobj', 'gtable', 'isoband', 'scales', 'brio', 'praise', 'waldo', 'ellipsis', 'generics', 'tidyr', 'ggplot2', 'tidyselect', 'Matrix', 'testthat', 'broom', 'dplyr', 'numDeriv', 'SparseM', 'MatrixModels', 'sp', 'minqa', 'nloptr', 'Rcpp', 'RcppEigen', 'carData', 'abind', 'pbkrtest', 'quantreg', 'maptools', 'lme4'

# %%
data(Prestige)
attach(Prestige)
names(Prestige)

# %%
scatterplot(education,income)

# %%
scatterplot(education,income,labels=rownames(Prestige))
detach(Prestige)

# %%
pairs(iris[1:4])
# Out:
# plot without title

# %%
pairs(iris[1:4],pch=21,bg=c("red","green3","blue")[unclass(iris$Species)])
# Out:
# plot without title

# %%
install.packages("scatterplot3d"); 
library(scatterplot3d)
# Out:
# The downloaded binary packages are in
# 	/var/folders/qr/y9jw5mv175zf8hcs038xchyc0000gn/T//RtmppfnEou/downloaded_packages

# %%
scatterplot3d(iris[,2:4],pch=c(1:3)[unclass(iris[,5])],
color=unclass(iris[,5]))
# Out:
# plot without title

# %%
iris.lab<-c(rep("S",50),rep("C",50),rep("V",50))

# %%
scatterplot3d(iris[,2:4],pch=c(1:3)[unclass(iris[,5])],
color=unclass(iris[,5])) 		# �}4.12(a)
# Out:
# plot without title

# %%
plot(iris[,1:2])
op<-par(mar=c(8,6,4,2))
# Out:
# plot without title

# %%
plot(iris[,1:2])
par(op)
# Out:
# plot without title

# %%
op<-par(mfrow=c(2,2))
plot(iris[,2],iris[,3]); plot(iris[,2],iris[,4]);
boxplot(iris[,2]~iris[,5]); boxplot(iris[,3]~iris[,5]) # �}4.14 (a)
par(op)
op<-par(mfrow=c(2,2),mar=c(4,1,1,1))
plot(iris[,2],iris[,3]); plot(iris[,2],iris[,4]);
boxplot(iris[,2]~iris[,5]); boxplot(iris[,3]~iris[,5]) # �}4.14 (b)
par(op)
# Out:
# plot without title
